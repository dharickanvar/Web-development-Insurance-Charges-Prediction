# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre1.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)
x_train,x_test,y_train,y_test
# Out:
# (      age     bmi  children  sex_male  smoker_yes
#  1163   18  28.215         0     False       False
#  196    39  32.800         0     False       False
#  438    52  46.750         5     False       False
#  183    44  26.410         0     False       False
#  1298   33  27.455         2      True       False
#  ...   ...     ...       ...       ...         ...
#  763    27  26.030         0      True       False
#  835    42  35.970         2      True       False
#  1216   40  25.080         0      True       False
#  559    19  35.530         0      True       False
#  684    33  18.500         1     False       False
#
#  [936 rows x 5 columns],
#        age     bmi  children  sex_male  smoker_yes
#  578    52  30.200         1      True       False
#  610    47  29.370         1     False       False
#  569    48  40.565         2      True        True
#  1034   61  38.380         0      True       False
#  198    51  18.050         0     False       False
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
x_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.ensemble import RandomForestRegressor
Regressor=RandomForestRegressor(n_estimators=50,criterion='absolute_error',max_features='log2',random_state=0)
Regressor=Regressor.fit(x_train,y_train)
Regressor
# Out:
# C:\Anaconda\envs\webd\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(criterion='absolute_error', max_features='log2',
#                       n_estimators=50, random_state=0)

# %%
y_pred=Regressor.predict(x_test)
y_pred
# Out:
# array([10727.4099232,  9039.8109027, 43969.713727 , 13127.4464445,
#        10754.6211256, 10793.8000008,  2057.364916 , 10692.5564152,
#         7210.468307 ,  6725.162002 ,  6214.1981102, 12836.6464513,
#         8178.9128467,  5113.8385642, 22929.0750912, 11357.0561878,
#        13333.2040776,  4865.6885026,  6810.4381224, 31677.6782712,
#        23856.7836135, 14079.354458 , 11474.2204808, 26465.5227334,
#         3618.0625858,  6688.9730088,  4552.4477656,  7868.487845 ,
#         3855.279956 , 11077.4582354,  8563.3837242, 46370.132331 ,
#        14335.805728 , 14335.4206176, 17457.8495426,  4071.832552 ,
#         8540.132348 , 37628.0764216, 39226.158775 ,  2480.0585525,
#         6017.0211574,  3740.5893734, 21163.5584603, 47034.1845734,
#        36504.366788 ,  4401.0170858, 11368.7434108,  6545.914078 ,
#         6012.5346962, 12506.3612408,  4801.369858 ,  4627.9820724,
#        25625.8908606, 43624.5791438, 11673.350439 , 11602.135986 ,
# ...

# %%
Regressor.feature_importances_
# Out:
# array([0.32262233, 0.26930753, 0.04824072, 0.01360358, 0.34622584])

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.8716849080926139

# %%
import pickle
scaler_file="scaler_x.pkl"
pickle.dump(sc,open(scaler_file,"wb"))
sc=pickle.load(open("scaler_x.pkl",'rb'))

# %%
import pickle

# %%
filename="Finalized_RandomForest_Regression1.sav"

# %%
pickle.dump(Regressor,open(filename,'wb'))

# %%
loaded_module=pickle.load(open("Finalized_RandomForest_Regression1.sav",'rb'))

# %%
preinput=sc.transform([[27,35,0,1,0]])
preinput
# Out:
# C:\Anaconda\envs\webd\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.89047344,  0.68155638, -0.89833872,  1.02378711, -0.50466988]])

# %%
result=loaded_module.predict(preinput)
result
# Out:
# array([6748.8529852])
